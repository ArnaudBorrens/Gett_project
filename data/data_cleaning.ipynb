# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df_offers = pd.read_csv(r'C:\Users\arnau\Gett_project\data\data_offers.csv')

df_orders = pd.read_csv(r'C:\Users\arnau\Gett_project\data\data_orders.csv')

# %%
df_offers.head()
print(df_offers.shape)
df_offers.tail()
df_offers['order_gk'].value_counts()
# Out:
# (334363, 2)
# order_gk
# 3000622541299    9
# 3000591156831    9
# 3000592296546    9
# 3000623018231    9
# 3000582817158    9
#                 ..
# 3000599186936    1
# 3000594272454    1
# 3000628607809    1
# 3000589832090    1
# 3000557510943    1
# Name: count, Length: 97967, dtype: int64

# %%
df_orders.head()
print(df_orders.shape)
df_orders.tail()
# Out:
# (10716, 8)
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 10711       13:11:35         -0.975372        51.457846          NaN
# 10712       13:13:55         -0.975372        51.457846          NaN
# 10713       13:17:21         -0.972926        51.457693         60.0
# 10714       13:16:28         -0.975372        51.457846          NaN
# 10715       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 10711  3000599186906                 4                       0
# 10712  3000599186962                 4                       0
# 10713  3000599187034                 4                       1
# 10714  3000599187024                 4                       0
# 10715  3000592871241                 4                       1
#
#        cancellations_time_in_seconds
# 10711                           36.0
# 10712                            4.0
# 10713                           34.0
# 10714                            6.0
# 10715                           40.0

# %%
df_orders['order_gk'].value_counts()
# Out:
# order_gk
# 3000583041974    1
# 3000590782265    1
# 3000590781929    1
# 3000590807087    1
# 3000590806745    1
#                 ..
# 3000587756057    1
# 3000587655526    1
# 3000587756214    1
# 3000587806780    1
# 3000592871241    1
# Name: count, Length: 10716, dtype: int64

# %%
df_left = df_orders.merge(df_offers, how='left', on='order_gk')
df_inner = df_orders.merge(df_offers, how='inner', on='order_gk')
df_right = df_orders.merge(df_offers, how='right', on='order_gk')

# %%
print(df_left.shape)
print(df_inner.shape)
print(df_right.shape)
# Out:
# (34374, 9)
# (31268, 9)
# (334363, 9)

# %%
df_inner.isna().sum()
# Out:
# order_datetime                       0
# origin_longitude                     0
# origin_latitude                      0
# m_order_eta                      22904
# order_gk                             0
# order_status_key                     0
# is_driver_assigned_key               0
# cancellations_time_in_seconds     9473
# offer_id                             0
# dtype: int64

# %%
df_inner['order_gk'].value_counts()
# Out:
# order_gk
# 3000598136195    9
# 3000590506922    9
# 3000590107346    9
# 3000587781203    9
# 3000587906535    9
#                 ..
# 3000582466475    1
# 3000582441338    1
# 3000582115602    1
# 3000580176445    1
# 3000592871241    1
# Name: count, Length: 7610, dtype: int64

# %%
df_inner[df_inner['order_gk']==3000598136195]
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 19133       22:30:06          -0.96466        51.422917          NaN
# 19134       22:30:06          -0.96466        51.422917          NaN
# 19135       22:30:06          -0.96466        51.422917          NaN
# 19136       22:30:06          -0.96466        51.422917          NaN
# 19137       22:30:06          -0.96466        51.422917          NaN
# 19138       22:30:06          -0.96466        51.422917          NaN
# 19139       22:30:06          -0.96466        51.422917          NaN
# 19140       22:30:06          -0.96466        51.422917          NaN
# 19141       22:30:06          -0.96466        51.422917          NaN
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 19133  3000598136195                 4                       0
# 19134  3000598136195                 4                       0
# 19135  3000598136195                 4                       0
# 19136  3000598136195                 4                       0
# 19137  3000598136195                 4                       0
# 19138  3000598136195                 4                       0
# 19139  3000598136195                 4                       0
# 19140  3000598136195                 4                       0
# 19141  3000598136195                 4                       0
#
#        cancellations_time_in_seconds      offer_id
# 19133                          116.0  300051601477
# 19134                          116.0  300051601443
# 19135                          116.0  300051601459
# 19136                          116.0  300051601456
# 19137                          116.0  300051601492
# 19138                          116.0  300051601460
# 19139                          116.0  300051601447
# 19140                          116.0  300051601453
# 19141                          116.0  300051601452

# %%
cancelled_before_after = df_orders.groupby('is_driver_assigned_key').count()['order_gk']

cancelled_before_after.rename({0: 'not_assigned', 1: 'assigned'},inplace=True)

cancelled_before_after
# Out:
# is_driver_assigned_key
# not_assigned    7902
# assigned        2814
# Name: order_gk, dtype: int64

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i] + 20, y[i], ha = 'center')

plt.bar(x=cancelled_before_after.index, height=cancelled_before_after.values)

plt.title('Orders with or without assigned drivers')
addlabels(cancelled_before_after.index, cancelled_before_after.values)
# plt.xlim(0,1)

plt.show()

# %%
cancelled_by_user_or_system = df_orders.groupby('order_status_key').count()['order_gk']

cancelled_by_user_or_system.rename({4: 'Cancelled by User', 9: 'Cancelled by System'}, inplace=True)

cancelled_by_user_or_system
# Out:
# order_status_key
# Cancelled by User      7307
# Cancelled by System    3409
# Name: order_gk, dtype: int64

# %%
plt.title('User cancelled VS System Cancelled')
plt.bar(x=cancelled_by_user_or_system.index, height=cancelled_by_user_or_system.values)
addlabels(cancelled_by_user_or_system.index, cancelled_by_user_or_system.values)

# %%
df_orders['Hour'] = pd.to_datetime(df_orders['order_datetime'], format= '%H:%M:%S').dt.hour

df_orders
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0           18:08:07         -0.978916        51.456173         60.0
# 1           20:57:32         -0.950385        51.456843          NaN
# 2           12:07:50         -0.969520        51.455544        477.0
# 3           13:50:20         -1.054671        51.460544        658.0
# 4           21:24:45         -0.967605        51.458236          NaN
# ...              ...               ...              ...          ...
# 10711       13:11:35         -0.975372        51.457846          NaN
# 10712       13:13:55         -0.975372        51.457846          NaN
# 10713       13:17:21         -0.972926        51.457693         60.0
# 10714       13:16:28         -0.975372        51.457846          NaN
# 10715       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 0      3000583041974                 4                       1
# 1      3000583116437                 4                       0
# 2      3000582891479                 4                       1
# 3      3000582941169                 4                       1
# 4      3000583140877                 9                       0
# ...              ...               ...                     ...
# 10711  3000599186906                 4                       0
# 10712  3000599186962                 4                       0
# 10713  3000599187034                 4                       1
# 10714  3000599187024                 4                       0
# 10715  3000592871241                 4                       1
#
#        cancellations_time_in_seconds  Hour
# 0                              198.0    18
# 1                              128.0    20
# 2                               46.0    12
# 3                               62.0    13
# 4                                NaN    21
# ...                              ...   ...
# 10711                           36.0    13
# 10712                            4.0    13
# 10713                           34.0    13
# 10714                            6.0    13
# 10715                           40.0    11
#
# [10716 rows x 9 columns]

# %%
cancelled_by_hour = df_orders.groupby('Hour').count()['order_gk']

# %%
plt.bar(x=cancelled_by_hour.index, height=cancelled_by_hour.values)
# Out:
# <BarContainer object of 24 artists>

# %%
plt.hist(data=df_orders, x='Hour', bins=24, width=1)
# Out:
# (array([ 683.,  471.,  555.,  513.,  152.,   67.,  159.,  447., 1082.,
#          412.,  170.,  193.,  256.,  366.,  256.,  439.,  356.,  541.,
#          414.,  317.,  469.,  846.,  716.,  836.]),
#  array([ 0.        ,  0.95833333,  1.91666667,  2.875     ,  3.83333333,
#          4.79166667,  5.75      ,  6.70833333,  7.66666667,  8.625     ,
#          9.58333333, 10.54166667, 11.5       , 12.45833333, 13.41666667,
#         14.375     , 15.33333333, 16.29166667, 17.25      , 18.20833333,
#         19.16666667, 20.125     , 21.08333333, 22.04166667, 23.        ]),
#  <BarContainer object of 24 artists>)

# %%
plt.figure(figsize=(20,10))
plt.title('Cancellations by Hour', pad=20)
sns.histplot(data=df_orders, x='Hour', binrange=(0,24), binwidth=1, discrete=True, hue='is_driver_assigned_key', multiple='stack')
plt.xlim(-1,24)
plt.xticks(range(0,24))
plt.ylim(0,1200)
# Out:
# (0.0, 1200.0)

# %%
plt.figure(figsize=(20,10))
plt.title('Cancellations by Hour', pad=20)
ax = sns.histplot(data=df_orders, x='Hour', binrange=(0,24), binwidth=1, discrete=True, hue='is_driver_assigned_key', multiple='stack', palette='Greys')
plt.xlim(-1,24)
plt.xticks(range(0,24))
plt.ylim(0,1200)

heights = [p.get_height() for p in ax.patches]
third_highest = sorted(heights)[-3]
for p in ax.patches:
    if  p.get_height() >= third_highest:
        p.set_facecolor('blue')

plt.show()

# %% [markdown]
# To obtain the desired graph I could supperpose 4 different graphs.
# 1 Graph showing the total count of failed orders, next a graph showing the failed orders where a driver was assigned. (This would give me the same graph as now)

# %%
assigned_drivers_df = df_orders[df_orders['is_driver_assigned_key'] == 1].copy()

assigned_drivers_df
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0           18:08:07         -0.978916        51.456173         60.0
# 2           12:07:50         -0.969520        51.455544        477.0
# 3           13:50:20         -1.054671        51.460544        658.0
# 13          16:55:28         -0.950683        51.451368        538.0
# 14          00:59:26         -0.937006        51.448696        179.0
# ...              ...               ...              ...          ...
# 10701       23:53:09         -0.976553        51.455485        178.0
# 10703       13:15:55         -0.975372        51.457846         60.0
# 10704       13:12:51         -0.975372        51.457846         60.0
# 10713       13:17:21         -0.972926        51.457693         60.0
# 10715       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 0      3000583041974                 4                       1
# 2      3000582891479                 4                       1
# 3      3000582941169                 4                       1
# 13     3000583016613                 4                       1
# 14     3000582566041                 4                       1
# ...              ...               ...                     ...
# 10701  3000589481691                 4                       1
# 10703  3000599187005                 4                       1
# 10704  3000599186936                 4                       1
# 10713  3000599187034                 4                       1
# 10715  3000592871241                 4                       1
#
#        cancellations_time_in_seconds  Hour
# 0                              198.0    18
# 2                               46.0    12
# 3                               62.0    13
# 13                             188.0    16
# 14                             316.0     0
# ...                              ...   ...
# 10701                          833.0    23
# 10703                           28.0    13
# 10704                           59.0    13
# 10713                           34.0    13
# 10715                           40.0    11
#
# [2814 rows x 9 columns]

# %%
# We first start by importing Rectangle from matplotlib to be able to draw customized shapes onto our Graph

from matplotlib.patches import Rectangle

# Let's then define the space inwhich we will draw our graph along with the title.
# As we only want to see 24 hours we set the limit of the x axis to 24, and for the y-axis we set the maximum limit to 1200
# Lastly we rename the y-axis label to make it understandable that we are plotting the cancelled orders

plt.figure(figsize=(20,10))
plt.title('Cancellations by Hour', pad=10)
plt.xlim(-1,24)
plt.xticks(range(0,24))
plt.ylim(0,1200)
plt.ylabel('Number of cancelled orders')


# We start by plotting the total numober of cancelled orders by hours
# and then add another plot on top to show the proportion of cancelled orders that had an assigned driver
# Lastly to make our plot more readable we add a legend to it.

ax = sns.histplot(data=df_orders, x='Hour', binrange=(0,24), binwidth=1, discrete=True, color='#D3D3D3')

sns.histplot(data=assigned_drivers_df, x='Hour', binrange=(0,24), binwidth=1, discrete=True, color='#5A5A5A')

plt.legend(labels=['Assigned Driver', 'Not Assigned Driver'])

# As this plot doesn't highlight anything in particular we want to make the top 3 hours with the most cancellation stand out.
# Therefore we first get a list of heights from our plot and assigning it to a 'heights' list.
# Then we get the height of the hour with the 3rd most cancellation and assign it to the variable 'third_highest'.
# Using an if statement we check if the ax.patches height is higher or equal to this height and if True set a determined color.
# As we also want this rectangle to have borders we add a empty rectangle with black borders on top of the graph.
# Lastly, we want to see exactly how many orders were cancelled in these three hours so we use the plt.text method to add it to the graph.

heights = [p.get_height() for p in ax.patches]
third_highest = sorted(heights)[-3]
for p in ax.patches:
    if  p.get_height() >= third_highest:
        p.set_color('#37BDB5')
        ax.add_patch( Rectangle(p.get_xy(), width=1, height=p.get_height(), fc='None', ec='black'))
        plt.text(x=p.get_x()+0.5, y=p.get_height() + 20, s= p.get_height(), ha='center')


# To change slightly the color of the background of the plot we change it to this warmer color

ax.set_facecolor('#FFFBF0')

plt.show()

# %%
# We first start by importing Rectangle from matplotlib to be able to draw customized shapes onto our Graph

from matplotlib.patches import Rectangle

# Let's then define the space inwhich we will draw our graph along with the title.
# As we only want to see 24 hours we set the limit of the x axis to 24, and for the y-axis we set the maximum limit to 1200
# Lastly we rename the y-axis label to make it understandable that we are plotting the cancelled orders

plt.figure(figsize=(20,10))
plt.title('Cancellations by Hour', pad=10)
plt.xlim(-1,24)
plt.xticks(range(0,24))
plt.ylim(0,1200)
plt.ylabel('Number of cancelled orders')


# We start by plotting the total numober of cancelled orders by hours
# and then add another plot on top to show the proportion of cancelled orders that had an assigned driver
# Lastly to make our plot more readable we add a legend to it.

ax = sns.histplot(data=df_orders, x='Hour', binrange=(0,24), binwidth=1, discrete=True, color='#D3D3D3')

sns.histplot(data=assigned_drivers_df, x='Hour', binrange=(0,24), binwidth=1, discrete=True, color='#5A5A5A')

plt.legend(labels=['Not Assigned Driver', 'Assigned Driver'])

# As this plot doesn't highlight anything in particular we want to make the top 3 hours with the most cancellation stand out.
# Therefore we first get a list of heights from our plot and assigning it to a 'heights' list.
# Then we get the height of the hour with the 3rd most cancellation and assign it to the variable 'third_highest'.
# Using an if statement we check if the ax.patches height is higher or equal to this height and if True set a determined color.
# Lastly, we want to see exactly how many orders were cancelled in these three hours so we use the plt.text method to add it to the graph.

heights = [p.get_height() for p in ax.patches]

third_highest = sorted(heights)[-3]
for p in ax.patches:
    if  p.get_height() >= third_highest:
        p.set_facecolor('#37BDB5')
        plt.text(x=p.get_x()+0.5, y=p.get_height() + 20, s= p.get_height(), ha='center')


# To change slightly the color of the background of the plot we change it to this warmer color

ax.set_facecolor('#FFFBF0')

plt.show()

# %% [markdown]
# Check if possible with one histplot. Problem is only the labelling of the total.

# %%
plt.figure(figsize=(20,10))
plt.title('Cancellations by Hour', pad=10)
plt.xlim(-1,24)
plt.xticks(range(0,24))
plt.ylim(0,1200)
plt.ylabel('Cancelled orders')

palette = ['#D3D3D3','#5A5A5A', '#37BDB5']

ax = sns.histplot(data=df_orders, x='Hour', binrange=(0,24), binwidth=1, discrete=True, hue='is_driver_assigned_key', multiple='stack', legend=False , palette=palette)
plt.legend(labels=['Not Assigned Driver', 'Assigned Driver'])

heights = [p.get_height() for p in ax.patches]
third_highest = sorted(heights)[-3]
for p in ax.patches:
    if  p.get_height() >= third_highest:
        p.set_facecolor(palette[2])
        #plt.text(x=p.get_x()+0.5, y=p.get_height() + 20, s= '{:,}'.format(p.get_height()), ha='center')
        p.bar_label(ax.containers[1])

ax.set_facecolor('#FFFBF0')
# Out:
# C:\Users\arnau\AppData\Local\Temp\ipykernel_25068\2287260542.py:10: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   ax = sns.histplot(data=df_orders, x='Hour', binrange=(0,24), binwidth=1, discrete=True, hue='is_driver_assigned_key', multiple='stack', legend=False , palette=palette)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\arnau\Gett_project\data\data_cleaning.ipynb Cell 25 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/arnau/Gett_project/data/data_cleaning.ipynb#X33sZmlsZQ%3D%3D?line=16'>17</a>         p.set_facecolor(palette[2])
#      <a href='vscode-notebook-cell:/c%3A/Users/arnau/Gett_project/data/data_cleaning.ipynb#X33sZmlsZQ%3D%3D?line=17'>18</a>         #plt.text(x=p.get_x()+0.5, y=p.get_height() + 20, s= '{:,}'.format(p.get_height()), ha='center')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/arnau/Gett_project/data/data_cleaning.ipynb#X33sZmlsZQ%3D%3D?line=18'>19</a>         p.bar_label(ax.containers[1])
#      <a href='vscode-notebook-cell:/c%3A/Users/arnau/Gett_project/data/data_cleaning.ipynb#X33sZmlsZQ%3D%3D?line=20'>21</a> ax.set_facecolor('#FFFBF0')
#
# AttributeError: 'Rectangle' object has no attribute 'bar_label'

# %%
system_cancelled_df = df_orders[df_orders['order_status_key'] == 9]


print(system_cancelled_df.shape)
print(system_cancelled_df.isna().sum())
# Out:
# (3409, 9)
# order_datetime                      0
# origin_longitude                    0
# origin_latitude                     0
# m_order_eta                      3406
# order_gk                            0
# order_status_key                    0
# is_driver_assigned_key              0
# cancellations_time_in_seconds    3409
# Hour                                0
# dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.title('Cancellations by Hour', pad=10)
plt.xlim(-1,24)
plt.xticks(range(0,24))
plt.ylim(0,1200)
plt.ylabel('Number of cancelled orders')

ax = sns.histplot(data=df_orders, x='Hour', binrange=(0,24), binwidth=1, discrete=True, color='#D3D3D3')

sns.histplot(data=system_cancelled_df, x='Hour', binrange=(0,24), binwidth=1, discrete=True, color='#5A5A5A')

plt.legend(labels=['User Cancelled', 'System Cancelled'])


heights = [p.get_height() for p in ax.patches]
third_highest = sorted(heights)[-3]
for p in ax.patches:
    if  p.get_height() >= third_highest:
        p.set_facecolor('#37BDB5')
        plt.text(x=p.get_x()+0.5, y=p.get_height() + 20, s= '{:,}'.format(p.get_height()), ha='center')


# To change slightly the color of the background of the plot we change it to this warmer color

ax.set_facecolor('#FFFBF0')

plt.show()

# %%
plt.figure(figsize=(20,10))
plt.title('Cancellations by Hour', pad=20)
ax = sns.histplot(data=df_orders, x='Hour', binrange=(0,24), binwidth=1, discrete=True, hue='order_status_key', multiple='stack')
plt.xlim(-1,24)
plt.xticks(range(0,24))
plt.ylim(0,1200)
ax.bar_label(ax.containers[0]);

# %%
assigned_drivers_df.head()
# Out:
#    order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0        18:08:07         -0.978916        51.456173         60.0
# 2        12:07:50         -0.969520        51.455544        477.0
# 3        13:50:20         -1.054671        51.460544        658.0
# 13       16:55:28         -0.950683        51.451368        538.0
# 14       00:59:26         -0.937006        51.448696        179.0
#
#          order_gk  order_status_key  is_driver_assigned_key  \
# 0   3000583041974                 4                       1
# 2   3000582891479                 4                       1
# 3   3000582941169                 4                       1
# 13  3000583016613                 4                       1
# 14  3000582566041                 4                       1
#
#     cancellations_time_in_seconds  Hour
# 0                           198.0    18
# 2                            46.0    12
# 3                            62.0    13
# 13                          188.0    16
# 14                          316.0     0

# %%
assigned_drivers_df.isna().sum()
# Out:
# order_datetime                   0
# origin_longitude                 0
# origin_latitude                  0
# m_order_eta                      0
# order_gk                         0
# order_status_key                 0
# is_driver_assigned_key           0
# cancellations_time_in_seconds    3
# Hour                             0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.title('Average cancellations times by hours')
sns.barplot(data=df_orders, x='Hour', y='cancellations_time_in_seconds', hue='is_driver_assigned_key');

# %%
df_orders.isna().sum()
# Out:
# order_datetime                      0
# origin_longitude                    0
# origin_latitude                     0
# m_order_eta                      7902
# order_gk                            0
# order_status_key                    0
# is_driver_assigned_key              0
# cancellations_time_in_seconds    3409
# Hour                                0
# dtype: int64

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10716 entries, 0 to 10715
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_datetime                 10716 non-null  object
#  1   origin_longitude               10716 non-null  float64
#  2   origin_latitude                10716 non-null  float64
#  3   m_order_eta                    2814 non-null   float64
#  4   order_gk                       10716 non-null  int64
#  5   order_status_key               10716 non-null  int64
#  6   is_driver_assigned_key         10716 non-null  int64
#  7   cancellations_time_in_seconds  7307 non-null   float64
#  8   Hour                           10716 non-null  int32
# dtypes: float64(4), int32(1), int64(3), object(1)
# memory usage: 711.7+ KB

# %%
df_orders['cancellations_time_in_seconds'].median()
# Out:
# 98.0

# %%
plt.figure(figsize=(10,5))
plt.ylim(0, 2)
#plt.xlim(-5, 5000)
plt.xticks(np.arange(0,4500,500))
sns.boxplot(data=df_orders, x='cancellations_time_in_seconds', y='is_driver_assigned_key', hue='is_driver_assigned_key', legend=False, orient='h');

# %%
df_orders['cancellations_time_in_seconds'].describe()

df_orders_by_driver_key = df_orders.groupby('is_driver_assigned_key')

df_orders_by_driver_key

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df_orders, x='cancellations_time_in_seconds', bins=50, hue='is_driver_assigned_key', multiple='stack')
plt.xlim(-100,5000)
plt.xticks(np.arange(0,4500,250));

# %%
df_orders.isna().sum()
# Out:
# order_datetime                      0
# origin_longitude                    0
# origin_latitude                     0
# m_order_eta                      7902
# order_gk                            0
# order_status_key                    0
# is_driver_assigned_key              0
# cancellations_time_in_seconds    3409
# Hour                                0
# dtype: int64

# %%
df_orders_na_replaced = df_orders.fillna(value={'cancellations_time_in_seconds':'missing'})

# %%
df_orders_na_replaced
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 0           18:08:07         -0.978916        51.456173         60.0
# 1           20:57:32         -0.950385        51.456843          NaN
# 2           12:07:50         -0.969520        51.455544        477.0
# 3           13:50:20         -1.054671        51.460544        658.0
# 4           21:24:45         -0.967605        51.458236          NaN
# ...              ...               ...              ...          ...
# 10711       13:11:35         -0.975372        51.457846          NaN
# 10712       13:13:55         -0.975372        51.457846          NaN
# 10713       13:17:21         -0.972926        51.457693         60.0
# 10714       13:16:28         -0.975372        51.457846          NaN
# 10715       11:49:35         -0.974738        51.458180        177.0
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 0      3000583041974                 4                       1
# 1      3000583116437                 4                       0
# 2      3000582891479                 4                       1
# 3      3000582941169                 4                       1
# 4      3000583140877                 9                       0
# ...              ...               ...                     ...
# 10711  3000599186906                 4                       0
# 10712  3000599186962                 4                       0
# 10713  3000599187034                 4                       1
# 10714  3000599187024                 4                       0
# 10715  3000592871241                 4                       1
#
#       cancellations_time_in_seconds  Hour
# 0                             198.0    18
# 1                             128.0    20
# 2                              46.0    12
# 3                              62.0    13
# 4                           missing    21
# ...                             ...   ...
# 10711                          36.0    13
# 10712                           4.0    13
# 10713                          34.0    13
# 10714                           6.0    13
# 10715                          40.0    11
#
# [10716 rows x 9 columns]

# %%
df_orders_na_replaced_missing = df_orders_na_replaced[df_orders_na_replaced['cancellations_time_in_seconds'] == 'missing']

df_orders_na_replaced_missing
# Out:
#       order_datetime  origin_longitude  origin_latitude  m_order_eta  \
# 4           21:24:45         -0.967605        51.458236          NaN
# 5           21:21:23         -0.947011        51.456380          NaN
# 6           07:58:15         -0.955637        51.470372          NaN
# 7           07:53:46         -0.978230        51.454575          NaN
# 8           08:53:01         -1.052298        51.454308          NaN
# ...              ...               ...              ...          ...
# 10673       14:55:53         -0.924138        51.436341          NaN
# 10682       08:04:58         -0.976793        51.462002          NaN
# 10684       08:08:36         -0.972801        51.478548          NaN
# 10685       23:33:46         -0.964696        51.445968          NaN
# 10691       20:57:37         -0.985994        51.456188          NaN
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 4      3000583140877                 9                       0
# 5      3000583117054                 9                       0
# 6      3000582791789                 9                       0
# 7      3000582791562                 9                       0
# 8      3000582817606                 9                       0
# ...              ...               ...                     ...
# 10673  3000554896655                 9                       0
# 10682  3000554721763                 9                       0
# 10684  3000554721897                 9                       0
# 10685  3000555121226                 9                       0
# 10691  3000555046587                 9                       0
#
#       cancellations_time_in_seconds  Hour
# 4                           missing    21
# 5                           missing    21
# 6                           missing     7
# 7                           missing     7
# 8                           missing     8
# ...                             ...   ...
# 10673                       missing    14
# 10682                       missing     8
# 10684                       missing     8
# 10685                       missing    23
# 10691                       missing    20
#
# [3409 rows x 9 columns]

# %%
sns.histplot(data=df_orders_na_replaced_missing, x='Hour', hue='order_status_key', binrange=(0,24), binwidth=1, discrete=True)
# Out:
# <Axes: xlabel='Hour', ylabel='Count'>

# %%
df_orders_eta_na = df_orders.fillna(value={'m_order_eta': 'no_eta'}).copy()

df_orders_eta_na_missig = df_orders_eta_na[df_orders_eta_na['m_order_eta']== 'no_eta']

df_orders_eta_na_missig
# Out:
#       order_datetime  origin_longitude  origin_latitude m_order_eta  \
# 1           20:57:32         -0.950385        51.456843      no_eta
# 4           21:24:45         -0.967605        51.458236      no_eta
# 5           21:21:23         -0.947011        51.456380      no_eta
# 6           07:58:15         -0.955637        51.470372      no_eta
# 7           07:53:46         -0.978230        51.454575      no_eta
# ...              ...               ...              ...         ...
# 10709       12:44:11         -0.975372        51.457846      no_eta
# 10710       12:42:52         -0.975372        51.457846      no_eta
# 10711       13:11:35         -0.975372        51.457846      no_eta
# 10712       13:13:55         -0.975372        51.457846      no_eta
# 10714       13:16:28         -0.975372        51.457846      no_eta
#
#             order_gk  order_status_key  is_driver_assigned_key  \
# 1      3000583116437                 4                       0
# 4      3000583140877                 9                       0
# 5      3000583117054                 9                       0
# 6      3000582791789                 9                       0
# 7      3000582791562                 9                       0
# ...              ...               ...                     ...
# 10709  3000597886155                 4                       0
# 10710  3000597886140                 4                       0
# 10711  3000599186906                 4                       0
# 10712  3000599186962                 4                       0
# 10714  3000599187024                 4                       0
#
#        cancellations_time_in_seconds  Hour
# 1                              128.0    20
# 4                                NaN    21
# 5                                NaN    21
# 6                                NaN     7
# 7                                NaN     7
# ...                              ...   ...
# 10709                           43.0    12
# 10710                           44.0    12
# 10711                           36.0    13
# 10712                            4.0    13
# 10714                            6.0    13
#
# [7902 rows x 9 columns]

# %%
sns.histplot(data=df_orders_eta_na_missig, x='Hour', hue='is_driver_assigned_key', discrete=True, multiple='stack')
# Out:
# <Axes: xlabel='Hour', ylabel='Count'>
